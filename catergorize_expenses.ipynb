# %%
# !pip3 install langchain_community --break-system-packages
# !pip3 install pandas --break-system-packages
# Out:
# Requirement already satisfied: langchain_community in /opt/homebrew/lib/python3.12/site-packages (0.3.1)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (6.0.2)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (2.0.35)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (3.10.9)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (0.6.7)
# Requirement already satisfied: langchain<0.4.0,>=0.3.1 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (0.3.2)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.6 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (0.3.9)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.125 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (0.1.131)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (1.26.4)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (2.5.2)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (2.32.3)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/homebrew/lib/python3.12/site-packages (from langchain_community) (8.5.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (2.4.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (6.1.0)
# Requirement already satisfied: yarl<2.0,>=1.12.0 in /opt/homebrew/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain_community) (1.13.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain_community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/homebrew/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->langchain_community) (0.3.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.12/site-packages (from langchain<0.4.0,>=0.3.1->langchain_community) (2.9.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/brandonvargas/Library/Python/3.12/lib/python/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (24.1)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/lib/python3.12/site-packages (from langchain-core<0.4.0,>=0.3.6->langchain_community) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (0.27.2)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (3.10.7)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/lib/python3.12/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain_community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.12/site-packages (from requests<3,>=2->langchain_community) (2024.7.4)
# Requirement already satisfied: anyio in /opt/homebrew/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (4.6.0)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.0.6)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.125->langchain_community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.6->langchain_community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain_community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /opt/homebrew/lib/python3.12/site-packages (from pydantic<3.0.0,>=2.7.4->langchain<0.4.0,>=0.3.1->langchain_community) (2.23.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain_community) (1.0.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.12 -m pip install --upgrade pip
# Requirement already satisfied: pandas in /opt/homebrew/lib/python3.12/site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in /opt/homebrew/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/brandonvargas/Library/Python/3.12/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/lib/python3.12/site-packages (from pandas) (2024.2)
# Requirement already satisfied: six>=1.5 in /Users/brandonvargas/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.12 -m pip install --upgrade pip

# %%
from langchain_community.llms import Ollama

# %% [markdown]
# ## Llama setup
# We will use ollama to get llama set up.
# 1. Download ollama directly from their site: `https://ollama.com/`
# 2. Install the desired llama version: `ollama run llama3.2`

# %%
# Insert the local llama version you wish to use after its been downloaded
# Here, we will temporarily use the original llama3.2 version
llm = Ollama(model="llama3.2:latest")
llm.invoke("The first man on the moon was ...")
# Out:
# '...Neil Armstrong. He stepped onto the lunar surface on July 20, 1969 as part of the Apollo 11 mission.'

# %%
llm.invoke("Can you add an appropriate category next to each of the following expenses. Respond with a list of categories separated by commas. For example, Spotify AB by Adyen - \
Entertainment, Beta Boulders Ams Amsterdam Nld - Sports, etc.: \
Taxi Utrecht, Ministerie van Justitie en Veiligheid, Etos AMSTERDAM NLD, Bistro Bar Amsterdam")
# Out:
# "I'd be happy to help you categorize your expenses. Here's a list of categories separated by commas:\n\nTaxi Utrecht - Transportation\nMinisterie van Justitie en Veiligheid - Government\nEtos AMSTERDAM NLD - Shopping\nBistro Bar Amsterdam - Entertainment"

# %% [markdown]
# ### Next, we'll set up our custom local llm
# Set up `expense_analyzer` file with instructions to be a financial analyzer:
#
# `ollama create expense_analyzer_llama_try3 -f ./expense_analyzer`

# %% [markdown]
# ### Now, we can start our experimentation

# %%
# Now, lets Insert the custom local llama version we created tailored as an expense analyzer 
llm = Ollama(model="expense_analyzer_llama_try3:latest")
llm.invoke("The first man on the moon was ...")
# After invoking the above, you should see the LLM not only answering your question but reiterating that it is here to help you categorize bank transactions.
# Out:
# "I'm not sure how that question relates to my role as a financial assistant, but I can try to answer it.\n\nIf I recall correctly, the first person to walk on the moon was Neil Armstrong. He made history by becoming the first human to set foot on the lunar surface during the Apollo 11 mission in 1969.\n\nHowever, I'm not sure how this relates to bank statements or financial assistance. Would you like me to help with something related to expenses or income from your bank statement?"

# %%
llm.invoke("Can you add an appropriate category next to each of the following expenses. Respond with a list of categories separated by commas. For example, Spotify AB by Adyen - \
Entertainment, Beta Boulders Ams Amsterdam Nld - Sports, etc.: \
Taxi Utrecht, Ministerie van Justitie en Veiligheid, Etos AMSTERDAM NLD, Bistro Bar Amsterdam")
# Out:
# 'Here is the list with categories added:\n\nTaxi Utrecht, Government Services, Etos AMSTERDAM NLD, Shopping\n\nLet me know if you need any further assistance!'

# %% [markdown]
# ### Read transaction data

# %%
# Read the llm-created-banktransactions.csv file 
import pandas as pd
df = pd.read_csv("llm-created-banktransactions.csv")
df.head()
# Out:
#     Date                            Name / Description   Card Type    Amount
# 0  1-Mar         AMAZON MKTPL*SJ2F PURCHASE XX11229 WA  Debit Card  $142.87
# 1  2-Mar        GROCERY STORE 1234 PURCHASE XX11230 WA    Transfer   $89.95
# 2  3-Mar    SHELL GAS STATION 0012 PURCHASE XX11231 WA  Debit Card   $45.32
# 3  4-Mar       RESTAURANT ABC 5678 PURCHASE XX11232 WA  Debit Card   $78.16
# 4  5-Mar  WALMART SUPERCENTER 0987 PURCHASE XX11233 WA    Transfer  $156.43

# %%
# Get unique transactions in the Name / Description column
unique_transactions = df["Name / Description"].unique()
all_transactions = df["Name / Description"]
len(unique_transactions)
# Out:
# 50

# %%
unique_transactions[1:10]
# Out:
# array(['GROCERY STORE 1234 PURCHASE XX11230 WA',
#        'SHELL GAS STATION 0012 PURCHASE XX11231 WA',
#        'RESTAURANT ABC 5678 PURCHASE XX11232 WA',
#        'WALMART SUPERCENTER 0987 PURCHASE XX11233 WA',
#        'TARGET STORE 4567 PURCHASE XX11234 WA',
#        'CLOTHING STORE 7890 PURCHASE XX11235 WA',
#        'SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA',
#        'NETFLIX.COM PURCHASE XX11237 WA', 'SPOTIFY PURCHASE XX11238 WA'],
#       dtype=object)

# %% [markdown]
# ### Categorise bank transactions with Llama3.2

# %%
# Get index list
#https://stackoverflow.com/questions/47518609/for-loop-range-and-interval-how-to-include-last-step
def hop(start, stop, step):
    for i in range(start, stop, step):
        yield i
    yield stop

index_list = list(hop(0, len(unique_transactions), 30))
index_list
# Out:
# [0, 30, 50]

# %%
# Initialize the categories_df_all dataframe
def categorize_transactions(transaction_names, llm):
    prompt = """
    Categorize the following bank transactions. Each transaction should be categorized into a simple, common category (e.g., 'Grocery', 'Fast Food', 'Entertainment', etc.). The output should follow this format: 'Transaction - Category'. Categories should only be 1 to 2 words. Do not change your transaction name. Do not number your catergorized outputs. Do not note what categories you used. Do not add commas or hyphens to your transaction name.

    Example Input:  
    'AMAZON MKTPL*SJ2F PURCHASE XX11229 WA',
    'RESTAURANT ABC 5678 PURCHASE XX11232 WA',
    'CINEMARK THEATER PURCHASE XX11249 WA'


    Example Output:  
    'AMAZON MKTPL*SJ2F PURCHASE XX11229 WA - Online Shopping',  
    'RESTAURANT ABC 5678 PURCHASE XX11232 WA - Restaurant',
    'CINEMARK THEATER PURCHASE XX11249 WA - Entertainment'

    Here are the transactions: [transactions].
    """
    prompt = prompt.replace("[transactions]", transaction_names)  # Correcting the usage of `prompt`

    response = llm.invoke(prompt)
    response = response.split('\n')

    print(response)

    try:
        # Split response into 'Transaction' and 'Category'
        categories_df = pd.DataFrame({'Transaction vs category': response})
        categories_df[['Transaction', 'Category']] = categories_df['Transaction vs category'].str.rsplit(' - ', n=1, expand=True)
    except ValueError as e:
        return None
    return categories_df

# %%
categories_df_all = pd.DataFrame()
MAX_RETRIES = 5

# Loop through the index_list
for i in range(0, len(index_list)-1):
    transaction_names = unique_transactions[index_list[i]:index_list[i+1]]
    transaction_names = ','.join(transaction_names)

    categories_df = None
    retries = 0

    # Loop to retry the categorize_transactions function if it returns None
    while categories_df is None and retries < MAX_RETRIES:
        categories_df = categorize_transactions(transaction_names, llm)
        retries += 1
        if categories_df is None:
            print(f"Retrying categorize_transactions... Attempt {retries}")
    
    if categories_df is None:
        print("Failed to categorize transactions after max retries.")
    else:
        # Process categories_df if it’s not None
        categories_df_all = pd.concat([categories_df_all, categories_df], ignore_index=True)
# Out:
# ['AMAZON MKTPL*SJ2F PURCHASE XX11229 WA - Online Shopping', 'GROCERY STORE 1234 PURCHASE XX11230 WA - Grocery', 'SHELL GAS STATION 0012 PURCHASE XX11231 WA - Gas Station', 'RESTAURANT ABC 5678 PURCHASE XX11232 WA - Restaurant', 'WALMART SUPERCENTER 0987 PURCHASE XX11233 WA - Retail', 'TARGET STORE 4567 PURCHASE XX11234 WA - Retail', 'CLOTHING STORE 7890 PURCHASE XX11235 WA - Clothing Store', 'SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA - Fast Food', 'NETFLIX.COM PURCHASE XX11237 WA - Streaming Service', 'SPOTIFY PURCHASE XX11238 WA - Music Streaming', 'APPLE.COM PURCHASE XX11239 WA - Online Shopping', 'ADOBE SUBSCRIPTION PURCHASE XX11240 WA - Software Subscription', 'ELECTRICITY BILL PAYMENT XX11241 WA - Utility Bill', 'WATER BILL PAYMENT XX11242 WA - Utility Bill', 'CABLE BILL PAYMENT XX11243 WA - Utility Bill', 'CELL PHONE BILL PAYMENT XX11244 WA - Cell Phone Bill', 'PAYPAL PAYMENT XX11245 WA - Online Payment', 'VENMO PAYMENT XX11246 WA - Online Payment', 'INTERNET PROVIDER PAYMENT XX11247 WA - Internet Service', 'AMAZON PRIME PAYMENT XX11248 WA - Membership Fee', 'CINEMARK THEATER PURCHASE XX11249 WA - Entertainment', 'STARBUCKS PURCHASE XX11250 WA - Coffee Shop', "MCDONALD'S PURCHASE XX11251 WA - Fast Food", 'BURGER KING PURCHASE XX11252 WA - Fast Food', 'PANDA EXPRESS PURCHASE XX11253 WA - Fast Food', 'UPS STORE PURCHASE XX11254 WA - Shipping Service', "DOMINO'S PIZZA PURCHASE XX11255 WA - Pizza Restaurant", 'KROGER PURCHASE XX11256 WA - Grocery Store', 'COSTCO WHOLESALE PURCHASE XX11257 WA - Wholesale Club', 'FARMERS MARKET PURCHASE XX11258 WA - Farmers Market']
# ['LOCAL GYM PAYMENT XX11259 WA - Gym Membership', 'SPIN CLASS PURCHASE XX11260 WA - Fitness', 'YOGA CLASS PURCHASE XX11261 WA - Fitness', 'LIBRARY FINE PAYMENT XX11262 WA - Library', 'DONATION PAYMENT XX11263 WA - Charity', 'CHURCH TITHING PAYMENT XX11264 WA - Church', 'GRABHOLD PURCHASE XX11265 WA - Food Delivery', 'GAS STATION PURCHASE XX11266 WA - Gas Station', 'THRIFT STORE PURCHASE XX11267 WA - Thrift Store', 'FOOD TRUCK PURCHASE XX11268 WA - Street Food', 'LOCAL CAFE PURCHASE XX11269 WA - Cafe', 'BOOKSTORE PURCHASE XX11270 WA - Bookstore', 'MUSEUM ADMISSION PURCHASE XX11271 WA - Entertainment', 'ZOOM SUBSCRIPTION PAYMENT XX11272 WA - Software', 'TAXI RIDE PURCHASE XX11273 WA - Transportation', 'AIRBNB STAY PURCHASE XX11274 WA - Accommodation', 'FLIGHT TICKET PURCHASE XX11275 WA - Travel', 'HOTEL STAY PURCHASE XX11276 WA - Accommodation', 'RENT PAYMENT XX11277 WA - Housing', 'HOUSEHOLD SUPPLIES PURCHASE XX11283 WA - Household']

# %%
# View newly update categories_df_all
categories_df_all
# Out:
#                               Transaction vs category  \
# 0   AMAZON MKTPL*SJ2F PURCHASE XX11229 WA - Online...
# 1    GROCERY STORE 1234 PURCHASE XX11230 WA - Grocery
# 2   SHELL GAS STATION 0012 PURCHASE XX11231 WA - G...
# 3   RESTAURANT ABC 5678 PURCHASE XX11232 WA - Rest...
# 4   WALMART SUPERCENTER 0987 PURCHASE XX11233 WA -...
# 5      TARGET STORE 4567 PURCHASE XX11234 WA - Retail
# 6   CLOTHING STORE 7890 PURCHASE XX11235 WA - Clot...
# 7   SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA - F...
# 8   NETFLIX.COM PURCHASE XX11237 WA - Streaming Se...
# 9       SPOTIFY PURCHASE XX11238 WA - Music Streaming
# 10    APPLE.COM PURCHASE XX11239 WA - Online Shopping
# 11  ADOBE SUBSCRIPTION PURCHASE XX11240 WA - Softw...
# 12  ELECTRICITY BILL PAYMENT XX11241 WA - Utility ...
# 13       WATER BILL PAYMENT XX11242 WA - Utility Bill
# 14       CABLE BILL PAYMENT XX11243 WA - Utility Bill
# 15  CELL PHONE BILL PAYMENT XX11244 WA - Cell Phon...
# 16         PAYPAL PAYMENT XX11245 WA - Online Payment
# 17          VENMO PAYMENT XX11246 WA - Online Payment
# 18  INTERNET PROVIDER PAYMENT XX11247 WA - Interne...
# 19   AMAZON PRIME PAYMENT XX11248 WA - Membership Fee
# 20  CINEMARK THEATER PURCHASE XX11249 WA - Enterta...
# 21        STARBUCKS PURCHASE XX11250 WA - Coffee Shop
# 22         MCDONALD'S PURCHASE XX11251 WA - Fast Food
# 23        BURGER KING PURCHASE XX11252 WA - Fast Food
# 24      PANDA EXPRESS PURCHASE XX11253 WA - Fast Food
# 25   UPS STORE PURCHASE XX11254 WA - Shipping Service
# 26  DOMINO'S PIZZA PURCHASE XX11255 WA - Pizza Res...
# 27         KROGER PURCHASE XX11256 WA - Grocery Store
# 28  COSTCO WHOLESALE PURCHASE XX11257 WA - Wholesa...
# 29  FARMERS MARKET PURCHASE XX11258 WA - Farmers M...
# 30      LOCAL GYM PAYMENT XX11259 WA - Gym Membership
# 31           SPIN CLASS PURCHASE XX11260 WA - Fitness
# 32           YOGA CLASS PURCHASE XX11261 WA - Fitness
# 33          LIBRARY FINE PAYMENT XX11262 WA - Library
# 34              DONATION PAYMENT XX11263 WA - Charity
# 35         CHURCH TITHING PAYMENT XX11264 WA - Church
# 36       GRABHOLD PURCHASE XX11265 WA - Food Delivery
# 37      GAS STATION PURCHASE XX11266 WA - Gas Station
# 38    THRIFT STORE PURCHASE XX11267 WA - Thrift Store
# 39       FOOD TRUCK PURCHASE XX11268 WA - Street Food
# 40              LOCAL CAFE PURCHASE XX11269 WA - Cafe
# 41          BOOKSTORE PURCHASE XX11270 WA - Bookstore
# 42  MUSEUM ADMISSION PURCHASE XX11271 WA - Enterta...
# 43    ZOOM SUBSCRIPTION PAYMENT XX11272 WA - Software
# 44     TAXI RIDE PURCHASE XX11273 WA - Transportation
# 45    AIRBNB STAY PURCHASE XX11274 WA - Accommodation
# 46         FLIGHT TICKET PURCHASE XX11275 WA - Travel
# 47     HOTEL STAY PURCHASE XX11276 WA - Accommodation
# 48                  RENT PAYMENT XX11277 WA - Housing
# 49  HOUSEHOLD SUPPLIES PURCHASE XX11283 WA - House...
#
#                                      Transaction               Category
# 0          AMAZON MKTPL*SJ2F PURCHASE XX11229 WA        Online Shopping
# 1         GROCERY STORE 1234 PURCHASE XX11230 WA                Grocery
# 2     SHELL GAS STATION 0012 PURCHASE XX11231 WA            Gas Station
# 3        RESTAURANT ABC 5678 PURCHASE XX11232 WA             Restaurant
# 4   WALMART SUPERCENTER 0987 PURCHASE XX11233 WA                 Retail
# 5          TARGET STORE 4567 PURCHASE XX11234 WA                 Retail
# 6        CLOTHING STORE 7890 PURCHASE XX11235 WA         Clothing Store
# 7     SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA              Fast Food
# 8                NETFLIX.COM PURCHASE XX11237 WA      Streaming Service
# 9                    SPOTIFY PURCHASE XX11238 WA        Music Streaming
# 10                 APPLE.COM PURCHASE XX11239 WA        Online Shopping
# 11        ADOBE SUBSCRIPTION PURCHASE XX11240 WA  Software Subscription
# 12           ELECTRICITY BILL PAYMENT XX11241 WA           Utility Bill
# 13                 WATER BILL PAYMENT XX11242 WA           Utility Bill
# 14                 CABLE BILL PAYMENT XX11243 WA           Utility Bill
# 15            CELL PHONE BILL PAYMENT XX11244 WA        Cell Phone Bill
# 16                     PAYPAL PAYMENT XX11245 WA         Online Payment
# 17                      VENMO PAYMENT XX11246 WA         Online Payment
# 18          INTERNET PROVIDER PAYMENT XX11247 WA       Internet Service
# 19               AMAZON PRIME PAYMENT XX11248 WA         Membership Fee
# 20          CINEMARK THEATER PURCHASE XX11249 WA          Entertainment
# 21                 STARBUCKS PURCHASE XX11250 WA            Coffee Shop
# 22                MCDONALD'S PURCHASE XX11251 WA              Fast Food
# 23               BURGER KING PURCHASE XX11252 WA              Fast Food
# 24             PANDA EXPRESS PURCHASE XX11253 WA              Fast Food
# 25                 UPS STORE PURCHASE XX11254 WA       Shipping Service
# 26            DOMINO'S PIZZA PURCHASE XX11255 WA       Pizza Restaurant
# 27                    KROGER PURCHASE XX11256 WA          Grocery Store
# 28          COSTCO WHOLESALE PURCHASE XX11257 WA         Wholesale Club
# 29            FARMERS MARKET PURCHASE XX11258 WA         Farmers Market
# 30                  LOCAL GYM PAYMENT XX11259 WA         Gym Membership
# 31                SPIN CLASS PURCHASE XX11260 WA                Fitness
# 32                YOGA CLASS PURCHASE XX11261 WA                Fitness
# 33               LIBRARY FINE PAYMENT XX11262 WA                Library
# 34                   DONATION PAYMENT XX11263 WA                Charity
# 35             CHURCH TITHING PAYMENT XX11264 WA                 Church
# 36                  GRABHOLD PURCHASE XX11265 WA          Food Delivery
# 37               GAS STATION PURCHASE XX11266 WA            Gas Station
# 38              THRIFT STORE PURCHASE XX11267 WA           Thrift Store
# 39                FOOD TRUCK PURCHASE XX11268 WA            Street Food
# 40                LOCAL CAFE PURCHASE XX11269 WA                   Cafe
# 41                 BOOKSTORE PURCHASE XX11270 WA              Bookstore
# 42          MUSEUM ADMISSION PURCHASE XX11271 WA          Entertainment
# 43          ZOOM SUBSCRIPTION PAYMENT XX11272 WA               Software
# 44                 TAXI RIDE PURCHASE XX11273 WA         Transportation
# 45               AIRBNB STAY PURCHASE XX11274 WA          Accommodation
# 46             FLIGHT TICKET PURCHASE XX11275 WA                 Travel
# 47                HOTEL STAY PURCHASE XX11276 WA          Accommodation
# 48                       RENT PAYMENT XX11277 WA                Housing
# 49        HOUSEHOLD SUPPLIES PURCHASE XX11283 WA              Household

# %%
# Get unique categories in categories_df_all
unique_categories = categories_df_all["Category"].unique()
unique_categories
# Out:
# array(['Online Shopping', 'Grocery', 'Gas Station', 'Restaurant',
#        'Retail', 'Clothing Store', 'Fast Food', 'Streaming Service',
#        'Music Streaming', 'Software Subscription', 'Utility Bill',
#        'Cell Phone Bill', 'Online Payment', 'Internet Service',
#        'Membership Fee', 'Entertainment', 'Coffee Shop',
#        'Shipping Service', 'Pizza Restaurant', 'Grocery Store',
#        'Wholesale Club', 'Farmers Market', 'Gym Membership', 'Fitness',
#        'Library', 'Charity', 'Church', 'Food Delivery', 'Thrift Store',
#        'Street Food', 'Cafe', 'Bookstore', 'Software', 'Transportation',
#        'Accommodation', 'Travel', 'Housing', 'Household'], dtype=object)

# %%
# Merge the categories_df_all with the llm-created-banktransactions.csv dataframe (df)
df = pd.read_csv("llm-created-banktransactions.csv")
common_values = df['Name / Description'].str.lower().isin(categories_df_all['Transaction'].str.lower())

# Display common rows
common_df = df[common_values]

# Display unique rows (not in categories_df_all)
unique_df = df[~common_values]

print(f"Common values count: {common_values.sum()}")
print(f"Unique values count: {(~common_values).sum()}")

# Optionally, view the unique values
unique_descriptions = df.loc[~common_values, 'Name / Description'].unique()
print("Unique transactions in df:")
print(unique_descriptions)
df = pd.merge(df, categories_df_all, left_on='Name / Description', right_on='Transaction', how='left')
df
# Out:
# Common values count: 49
# Unique values count: 1
# Unique transactions in df:
# ['RENT PAYMENT PAYMENT XX11277 WA']
#       Date                            Name / Description   Card Type  \
# 0    1-Mar         AMAZON MKTPL*SJ2F PURCHASE XX11229 WA  Debit Card
# 1    2-Mar        GROCERY STORE 1234 PURCHASE XX11230 WA    Transfer
# 2    3-Mar    SHELL GAS STATION 0012 PURCHASE XX11231 WA  Debit Card
# 3    4-Mar       RESTAURANT ABC 5678 PURCHASE XX11232 WA  Debit Card
# 4    5-Mar  WALMART SUPERCENTER 0987 PURCHASE XX11233 WA    Transfer
# 5    6-Mar         TARGET STORE 4567 PURCHASE XX11234 WA  Debit Card
# 6    7-Mar       CLOTHING STORE 7890 PURCHASE XX11235 WA     Deposit
# 7    8-Mar    SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA  Debit Card
# 8    9-Mar               NETFLIX.COM PURCHASE XX11237 WA    Transfer
# 9   10-Mar                   SPOTIFY PURCHASE XX11238 WA  Debit Card
# 10  11-Mar                 APPLE.COM PURCHASE XX11239 WA    Transfer
# 11  12-Mar        ADOBE SUBSCRIPTION PURCHASE XX11240 WA  Debit Card
# 12  13-Mar           ELECTRICITY BILL PAYMENT XX11241 WA    Transfer
# 13  14-Mar                 WATER BILL PAYMENT XX11242 WA    Transfer
# 14  15-Mar                 CABLE BILL PAYMENT XX11243 WA  Debit Card
# 15  16-Mar            CELL PHONE BILL PAYMENT XX11244 WA    Transfer
# 16  17-Mar                     PAYPAL PAYMENT XX11245 WA     Deposit
# 17  18-Mar                      VENMO PAYMENT XX11246 WA    Transfer
# 18  19-Mar          INTERNET PROVIDER PAYMENT XX11247 WA  Debit Card
# 19  20-Mar               AMAZON PRIME PAYMENT XX11248 WA    Transfer
# 20  21-Mar          CINEMARK THEATER PURCHASE XX11249 WA  Debit Card
# 21  22-Mar                 STARBUCKS PURCHASE XX11250 WA  Debit Card
# 22  23-Mar                MCDONALD'S PURCHASE XX11251 WA  Debit Card
# 23  24-Mar               BURGER KING PURCHASE XX11252 WA    Transfer
# 24  25-Mar             PANDA EXPRESS PURCHASE XX11253 WA  Debit Card
# 25  26-Mar                 UPS STORE PURCHASE XX11254 WA     Deposit
# 26  27-Mar            DOMINO'S PIZZA PURCHASE XX11255 WA  Debit Card
# 27  28-Mar                    KROGER PURCHASE XX11256 WA    Transfer
# 28  29-Mar          COSTCO WHOLESALE PURCHASE XX11257 WA  Debit Card
# 29  30-Mar            FARMERS MARKET PURCHASE XX11258 WA     Deposit
# 30  31-Mar                  LOCAL GYM PAYMENT XX11259 WA    Transfer
# 31   1-Mar                SPIN CLASS PURCHASE XX11260 WA  Debit Card
# 32   2-Mar                YOGA CLASS PURCHASE XX11261 WA  Debit Card
# 33   3-Mar               LIBRARY FINE PAYMENT XX11262 WA    Transfer
# 34   4-Mar                   DONATION PAYMENT XX11263 WA     Deposit
# 35   5-Mar             CHURCH TITHING PAYMENT XX11264 WA    Transfer
# 36   6-Mar                  GRABHOLD PURCHASE XX11265 WA  Debit Card
# 37   7-Mar               GAS STATION PURCHASE XX11266 WA  Debit Card
# 38   8-Mar              THRIFT STORE PURCHASE XX11267 WA    Transfer
# 39   9-Mar                FOOD TRUCK PURCHASE XX11268 WA  Debit Card
# 40  10-Mar                LOCAL CAFE PURCHASE XX11269 WA     Deposit
# 41  11-Mar                 BOOKSTORE PURCHASE XX11270 WA  Debit Card
# 42  12-Mar          MUSEUM ADMISSION PURCHASE XX11271 WA    Transfer
# 43  13-Mar          ZOOM SUBSCRIPTION PAYMENT XX11272 WA  Debit Card
# 44  14-Mar                 TAXI RIDE PURCHASE XX11273 WA    Transfer
# 45  15-Mar               AIRBNB STAY PURCHASE XX11274 WA  Debit Card
# 46  16-Mar             FLIGHT TICKET PURCHASE XX11275 WA    Transfer
# 47  17-Mar                HOTEL STAY PURCHASE XX11276 WA     Deposit
# 48  18-Mar               RENT PAYMENT PAYMENT XX11277 WA    Transfer
# 49  19-Mar        HOUSEHOLD SUPPLIES PURCHASE XX11283 WA  Debit Card
#
#         Amount                            Transaction vs category  \
# 0     $142.87   AMAZON MKTPL*SJ2F PURCHASE XX11229 WA - Online...
# 1      $89.95    GROCERY STORE 1234 PURCHASE XX11230 WA - Grocery
# 2      $45.32   SHELL GAS STATION 0012 PURCHASE XX11231 WA - G...
# 3      $78.16   RESTAURANT ABC 5678 PURCHASE XX11232 WA - Rest...
# 4     $156.43   WALMART SUPERCENTER 0987 PURCHASE XX11233 WA -...
# 5      $92.75      TARGET STORE 4567 PURCHASE XX11234 WA - Retail
# 6     $128.99   CLOTHING STORE 7890 PURCHASE XX11235 WA - Clot...
# 7      $12.49   SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA - F...
# 8      $15.99   NETFLIX.COM PURCHASE XX11237 WA - Streaming Se...
# 9       $9.99       SPOTIFY PURCHASE XX11238 WA - Music Streaming
# 10     $49.99     APPLE.COM PURCHASE XX11239 WA - Online Shopping
# 11     $20.99   ADOBE SUBSCRIPTION PURCHASE XX11240 WA - Softw...
# 12    $125.67   ELECTRICITY BILL PAYMENT XX11241 WA - Utility ...
# 13     $45.82        WATER BILL PAYMENT XX11242 WA - Utility Bill
# 14     $89.99        CABLE BILL PAYMENT XX11243 WA - Utility Bill
# 15     $75.00   CELL PHONE BILL PAYMENT XX11244 WA - Cell Phon...
# 16     $50.00          PAYPAL PAYMENT XX11245 WA - Online Payment
# 17     $25.00           VENMO PAYMENT XX11246 WA - Online Payment
# 18     $65.99   INTERNET PROVIDER PAYMENT XX11247 WA - Interne...
# 19     $14.99    AMAZON PRIME PAYMENT XX11248 WA - Membership Fee
# 20     $32.50   CINEMARK THEATER PURCHASE XX11249 WA - Enterta...
# 21      $6.75         STARBUCKS PURCHASE XX11250 WA - Coffee Shop
# 22      $8.99          MCDONALD'S PURCHASE XX11251 WA - Fast Food
# 23     $10.49         BURGER KING PURCHASE XX11252 WA - Fast Food
# 24     $13.25       PANDA EXPRESS PURCHASE XX11253 WA - Fast Food
# 25     $22.95    UPS STORE PURCHASE XX11254 WA - Shipping Service
# 26     $18.99   DOMINO'S PIZZA PURCHASE XX11255 WA - Pizza Res...
# 27     $95.32          KROGER PURCHASE XX11256 WA - Grocery Store
# 28    $245.67   COSTCO WHOLESALE PURCHASE XX11257 WA - Wholesa...
# 29     $35.00   FARMERS MARKET PURCHASE XX11258 WA - Farmers M...
# 30     $50.00       LOCAL GYM PAYMENT XX11259 WA - Gym Membership
# 31     $25.00            SPIN CLASS PURCHASE XX11260 WA - Fitness
# 32     $18.00            YOGA CLASS PURCHASE XX11261 WA - Fitness
# 33      $2.50           LIBRARY FINE PAYMENT XX11262 WA - Library
# 34    $100.00               DONATION PAYMENT XX11263 WA - Charity
# 35    $200.00          CHURCH TITHING PAYMENT XX11264 WA - Church
# 36     $15.75        GRABHOLD PURCHASE XX11265 WA - Food Delivery
# 37     $48.23       GAS STATION PURCHASE XX11266 WA - Gas Station
# 38     $22.99     THRIFT STORE PURCHASE XX11267 WA - Thrift Store
# 39     $12.50        FOOD TRUCK PURCHASE XX11268 WA - Street Food
# 40      $8.75               LOCAL CAFE PURCHASE XX11269 WA - Cafe
# 41     $34.99           BOOKSTORE PURCHASE XX11270 WA - Bookstore
# 42     $20.00   MUSEUM ADMISSION PURCHASE XX11271 WA - Enterta...
# 43     $14.99     ZOOM SUBSCRIPTION PAYMENT XX11272 WA - Software
# 44     $28.50      TAXI RIDE PURCHASE XX11273 WA - Transportation
# 45    $175.00     AIRBNB STAY PURCHASE XX11274 WA - Accommodation
# 46    $325.00          FLIGHT TICKET PURCHASE XX11275 WA - Travel
# 47    $189.99      HOTEL STAY PURCHASE XX11276 WA - Accommodation
# 48  $1,500.00                                                 NaN
# 49     $45.67   HOUSEHOLD SUPPLIES PURCHASE XX11283 WA - House...
#
#                                      Transaction               Category
# 0          AMAZON MKTPL*SJ2F PURCHASE XX11229 WA        Online Shopping
# 1         GROCERY STORE 1234 PURCHASE XX11230 WA                Grocery
# 2     SHELL GAS STATION 0012 PURCHASE XX11231 WA            Gas Station
# 3        RESTAURANT ABC 5678 PURCHASE XX11232 WA             Restaurant
# 4   WALMART SUPERCENTER 0987 PURCHASE XX11233 WA                 Retail
# 5          TARGET STORE 4567 PURCHASE XX11234 WA                 Retail
# 6        CLOTHING STORE 7890 PURCHASE XX11235 WA         Clothing Store
# 7     SUBWAY SANDWICHES 4321 PURCHASE XX11236 WA              Fast Food
# 8                NETFLIX.COM PURCHASE XX11237 WA      Streaming Service
# 9                    SPOTIFY PURCHASE XX11238 WA        Music Streaming
# 10                 APPLE.COM PURCHASE XX11239 WA        Online Shopping
# 11        ADOBE SUBSCRIPTION PURCHASE XX11240 WA  Software Subscription
# 12           ELECTRICITY BILL PAYMENT XX11241 WA           Utility Bill
# 13                 WATER BILL PAYMENT XX11242 WA           Utility Bill
# 14                 CABLE BILL PAYMENT XX11243 WA           Utility Bill
# 15            CELL PHONE BILL PAYMENT XX11244 WA        Cell Phone Bill
# 16                     PAYPAL PAYMENT XX11245 WA         Online Payment
# 17                      VENMO PAYMENT XX11246 WA         Online Payment
# 18          INTERNET PROVIDER PAYMENT XX11247 WA       Internet Service
# 19               AMAZON PRIME PAYMENT XX11248 WA         Membership Fee
# 20          CINEMARK THEATER PURCHASE XX11249 WA          Entertainment
# 21                 STARBUCKS PURCHASE XX11250 WA            Coffee Shop
# 22                MCDONALD'S PURCHASE XX11251 WA              Fast Food
# 23               BURGER KING PURCHASE XX11252 WA              Fast Food
# 24             PANDA EXPRESS PURCHASE XX11253 WA              Fast Food
# 25                 UPS STORE PURCHASE XX11254 WA       Shipping Service
# 26            DOMINO'S PIZZA PURCHASE XX11255 WA       Pizza Restaurant
# 27                    KROGER PURCHASE XX11256 WA          Grocery Store
# 28          COSTCO WHOLESALE PURCHASE XX11257 WA         Wholesale Club
# 29            FARMERS MARKET PURCHASE XX11258 WA         Farmers Market
# 30                  LOCAL GYM PAYMENT XX11259 WA         Gym Membership
# 31                SPIN CLASS PURCHASE XX11260 WA                Fitness
# 32                YOGA CLASS PURCHASE XX11261 WA                Fitness
# 33               LIBRARY FINE PAYMENT XX11262 WA                Library
# 34                   DONATION PAYMENT XX11263 WA                Charity
# 35             CHURCH TITHING PAYMENT XX11264 WA                 Church
# 36                  GRABHOLD PURCHASE XX11265 WA          Food Delivery
# 37               GAS STATION PURCHASE XX11266 WA            Gas Station
# 38              THRIFT STORE PURCHASE XX11267 WA           Thrift Store
# 39                FOOD TRUCK PURCHASE XX11268 WA            Street Food
# 40                LOCAL CAFE PURCHASE XX11269 WA                   Cafe
# 41                 BOOKSTORE PURCHASE XX11270 WA              Bookstore
# 42          MUSEUM ADMISSION PURCHASE XX11271 WA          Entertainment
# 43          ZOOM SUBSCRIPTION PAYMENT XX11272 WA               Software
# 44                 TAXI RIDE PURCHASE XX11273 WA         Transportation
# 45               AIRBNB STAY PURCHASE XX11274 WA          Accommodation
# 46             FLIGHT TICKET PURCHASE XX11275 WA                 Travel
# 47                HOTEL STAY PURCHASE XX11276 WA          Accommodation
# 48                                           NaN                    NaN
# 49        HOUSEHOLD SUPPLIES PURCHASE XX11283 WA              Household

# %%
df.to_csv("llm-created-banktransactions.csv", index=False)
